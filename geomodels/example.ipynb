# %%
from geomodels import *

# %%
search = 'geothermal energy future'
georecommend_find(search)
# Out:
#        index                                              title  \
# 6          6  Geothermal Circulation Systems is Environmenta...
# 29        29  Update on Thailand Geothermal Energy Research ...
# 39        39              The Renewability of Geothermal Energy
# 41        41                       Geothermal Energy in Finland
# 76        76  Geothermal Energy Potential and Utilization in...
# ...      ...                                                ...
# 18731   2462  Low Enthalpy Geothermal Energy Utilization for...
# 18732   2463  The Role of Geothermal Energy in the Locally D...
# 18751   2482               Norway's Geothermal Energy Situation
# 18765   2496  Status Report on Geothermal Energy Development...
# 18768   2499                   Geothermal Energy Use in Germany
#
#                                                  authors  \
# 6                                       Irina Moiseykina
# 29     Tavisakdi Ramingwong, Suthep Lertsrimongkol, P...
# ...
